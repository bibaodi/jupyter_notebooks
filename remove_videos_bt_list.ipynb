# %% [markdown]
# ### 删除列表中的文件夹
# 根据测试集合列表, 脏数据列表将视频从总的数据集中删除文件, 保留下来的作为训练数据集.

# %%
import os
import shutil
import tqdm

dirty_list_s = """
05_03_XX_Vessel_R_01
03_06_XX_Plaque_L_01
05_04_XX_Vessel_L_01
05_46_XX_Vessel_R_01
"""

testSet_list_s = """
05_44_XX_Vessel_L_01_frms
05_44_XX_Vessel_R_01_frms
05_54_XX_Vessel_R_01_frms
05_64_XX_Vessel_R_01_frms
05_70_XX_Vessel_L_01_frms
05_75_XX_Vessel_L_01_frms
05_75_XX_Vessel_L_02_frms
05_75_XX_Vessel_L_03_frms
05_76_XX_Vessel_L_01_frms
05_76_XX_Vessel_L_02_frms
05_77_XX_Vessel_L_01_frms
06_Plaque_XX_YY_15R_frms
06_Plaque_XX_YY_16L_frms
07_Plaque_01_YY_01_frms
07_Plaque_02_YY_01_frms
07_Plaque_09_YY_01_frms
07_Plaque_10_YY_01_frms
07_Plaque_13_YY_01_frms
07_Plaque_13_YY_02_frms
03_ScanEmpty_16
03_ScanEmpty_17
03_ScanEmpty_18
03_ScanEmpty_19
03_ScanEmpty_20
03_ScanEmpty_21
03_ScanEmpty_22
"""

dirty_list = [ i for i in dirty_list_s.split()]
print(dirty_list)
testSet_list = [i for i in testSet_list_s.split()]

def remove_dir_from_list(root_dir, r_list):
    if not os.path.isdir(root_dir):
        print(f"dir:{root_dir} invalid")
        return
    if not isinstance(r_list, list):
        print(f"r_list must be list")
        return
    
    os.chdir(root_dir)
    dirs = os.listdir(root_dir)
    for i in r_list:
        if i in dirs:
            shutil.rmtree(i)
            print(f"remove directory:{i}")
            
    return
# Out:
# ['05_03_XX_Vessel_R_01', '03_06_XX_Plaque_L_01', '05_04_XX_Vessel_L_01', '05_46_XX_Vessel_R_01']

# %%
def get_sub_set_by_list_file(root_dir, subsetdir, listfile):
    """
    从总的数据集中获取一个子集, 子集的名称在listfile中指定.
    rootdir: 绝对路径, 是数据所在目录
    subsetdir: 绝对路径, 新数据集合的目录
    listfile: 数据条目的名称列表文件
    return: True 成功, False失败
    """
    if not os.path.isdir(root_dir):
        print(f"rootdir:{root_dir} invalid")
        return False
    if not os.path.isdir(subsetdir):
        print(f"subsetdir:{subsetdir} invalid")
        return False
    if not os.path.isfile(listfile):
        print(f"listfile:{listfile} invalid")
        return False
    
    with open(listfile, 'r') as f:
        buf = f.read()
        sub_set = buf.split()
    for item in tqdm.tqdm(sub_set, ncols=80, desc="Processing Files:"):
        s = os.path.join(root_dir, item)
        d = os.path.join(subsetdir, item)
        print(f"copy from {s} to {d}")
        shutil.copytree(s,d)
    return True

# %%
get_sub_set_by_list_file(r"F:\tmpdata\scan_empty", r"F:\tmpdata\tmp191012", r"F:\tmpdata\tmp191012\listfile.txt")
# Out:
05_73_XX_Vessel_R_01_frms
05_74_XX_Vessel_R_01_frms
05_75_XX_Vessel_L_01_frms
05_75_XX_Vessel_L_02_frms
05_75_XX_Vessel_L_03_frms
05_76_XX_Vessel_L_01_frms
05_76_XX_Vessel_L_02_frms
05_77_XX_Vessel_L_01_frms
05_78_XX_Vessel_L_01_frms
05_78_XX_Vessel_R_01_frms
05_79_XX_Vessel_L_01_frms
05_79_XX_Vessel_L_02_frms
05_79_XX_Vessel_R_01_frms
05_79_XX_Vessel_R_03_frms
05_80_XX_Vessel_L_01_frms
06_Plaque_XX_YY_03_frms
06_Plaque_XX_YY_04_frms
06_Plaque_XX_YY_07_frms
03_20_XX_Plaque_R_01_frms
03_20_XX_Plaque_R_02_frms
03_24_XX_Plaque_L_01_frms
03_24_XX_Plaque_R_01_frms
03_26_XX_Plaque_L_01_frms
03_26_XX_Plaque_R_01_frms
03_28_XX_Plaque_R_01_frms
06_Plaque_XX_YY_01_frms
06_Plaque_XX_YY_02_frms
06_Plaque_XX_YY_05_frms
06_Plaque_XX_YY_06_frms
06_Plaque_XX_YY_08_frms
06_Plaque_XX_YY_09_frms
06_Plaque_XX_YY_10_frms
06_Plaque_XX_YY_11L_frms
06_Plaque_XX_YY_12R_frms
06_Plaque_XX_YY_13L_frms
07_Plaque_01_YY_01_frms
07_Plaque_02_YY_01_frms
07_Plaque_02_YY_02_frms
07_Plaque_03_YY_01_frms
07_Plaque_03_YY_02_frms
"""
p7all = p7all.split()
p6all = p6all.split()
delta=set(p7all)-set(p6all)
#print(delta, len(delta)
print('\r\n'.join(list(delta)))
# Out:
# 07_Plaque_19_YY_01_frms
# 07_Plaque_07_YY_02_frms
# 07_Plaque_24_YY_02_frms
# 07_Plaque_07_YY_01_frms
# 07_Plaque_22_YY_02_frms
# 07_Plaque_20_YY_01_frms
# 07_Plaque_11_YY_01_frms
# 06_Plaque_XX_YY_17_frms
# 07_Plaque_09_YY_01_frms
# 07_Plaque_05_YY_01_frms
# 07_Plaque_25_YY_01_frms
# 07_Plaque_16_YY_01_frms
# 07_Plaque_12_YY_02_frms
# 07_Plaque_13_YY_02_frms
# 06_Plaque_XX_YY_15R_frms
# 07_Plaque_23_YY_01_frms
# 07_Plaque_17_YY_01_frms
# 07_Plaque_10_YY_01_frms
# 07_Plaque_10_YY_02_frms
# 07_Plaque_04_YY_01_frms
# 07_Plaque_24_YY_01_frms
# 07_Plaque_13_YY_01_frms
# 07_Plaque_21_YY_01_frms
# 07_Plaque_12_YY_01_frms
# 07_Plaque_15_YY_01_frms
# 07_Plaque_14_YY_01_frms
# 07_Plaque_08_YY_01_frms
# 07_Plaque_18_YY_01_frms
# 07_Plaque_22_YY_01_frms
# 06_Plaque_XX_YY_14L_frms
# 06_Plaque_XX_YY_16L_frms

# %%
def list_minus_list(l1f, l2f):
